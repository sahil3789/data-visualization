# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1 = pd.read_csv("college_1.csv")
df2 = pd.read_csv("college_2.csv")

frames = [df1,df2]
df = pd.concat(frames)
df
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
df[df["CodeKata Score"]>15000].to_csv("Exceeded_expectations.csv")
df[(df["CodeKata Score"]>10000) & (df["CodeKata Score"]<15000)].to_csv("Reached_expectations.csv")
df[(df["CodeKata Score"]>7000) & (df["CodeKata Score"]>10000)].to_csv("Needs_Improvements.csv")
df[df["CodeKata Score"]<7000].to_csv("Unsatisfactory.csv")

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
x=df[["Previous Geekions","CodeKata Score"]].mean(axis=1)

# %% [markdown]
# ###### No of students participated

# %%
df[df["CodeKata Score"]>0]
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 28  M.Karthikeyan    -1.0    4.0               4020            4020
# 29      Abishak s    -1.0   35.0               3220            3220
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
df[["python","mysql","python_en","computational_thinking"]].mean(axis=1)
# Out:
# 0      51.00
# 1      51.00
# 2     100.00
# 3      73.50
# 4      54.00
#        ...
# 30      5.75
# 31     15.50
# 32     20.00
# 33      4.25
# 34     -0.75
# Length: 119, dtype: float64

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.sort_values(by=["CodeKata Score"],ascending=False).head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df.sort_values(by=["Previous Geekions"],ascending=False).head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
x=df.groupby(by="Department").sum("CodeKata Score")
scores = list(x["CodeKata Score"])
scores

colors = ['#FFB900','#83FF00','#FF3200']
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'CSE', 'ECE', 'EEE'

explode = (0.1, 0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(scores, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

dept = ('CSE', 'ECE', 'EEE')
y_pos = np.arange(len(dept))
score = list(df.groupby(['Department'], sort=False)['CodeKata Score'].max())

ax.barh(y_pos, score, align='center')
ax.set_yticks(y_pos, labels=dept)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('CodeKata Score')
ax.set_title('Department wise CodeKata Max Score')

plt.show()
